# %%
import pandas as pd
import csv
import json
import os
from PIL import Image, ImageDraw

# %%
data = pd.read_csv("../detection-tle-2-classifications.csv") 
output="output.csv"
rootPath = r"../dataset/images"
os.makedirs("annotations", exist_ok=True)

with open(output, mode='w') as csv_file:
    columns=["is_tle","event","subject_id","x","y","width","height","type"]
    write=csv.DictWriter(csv_file,fieldnames=columns)
    write.writeheader()
    i=0
    while (i<len(data)):
        is_tle=json.loads(data.iloc[i,11])[0]["value"]
        if is_tle=="Áno":
            anot=json.loads(data.iloc[i,11])[1]["value"]
            count=0
            while(count<len(anot)):
                event=json.loads(data.iloc[i,12])[str(data.iloc[i,13])]["Filename"]
                subject_id=json.loads(str(data.iloc[i,13]))
                
                x=json.loads(data.iloc[i,11])[1]["value"][count]["x"]
                y=json.loads(data.iloc[i,11])[1]["value"][count]["y"]
                width=json.loads(data.iloc[i,11])[1]["value"][count]["width"]
                height=json.loads(data.iloc[i,11])[1]["value"][count]["height"]
                type_tle=json.loads(data.iloc[i,11])[1]["value"][count]["tool_label"]
                
                write.writerow({'is_tle': is_tle,'event': event,'subject_id': subject_id,'x': x,'y':y,'width':width,'height':height,'type':type_tle})
                
                count+=1
                
            for root, dirs, files in os.walk(rootPath):
                for file in files:
                    if file == event:
                        im = Image.open(os.path.join(root, "%s" % (file)))
                        im1 = ImageDraw.Draw(im)
                        count=0
                        while(count<len(anot)):
                            if (type_tle == 'Mrkva (Carrot sprite)'):
                                shape=[(x, y), (x, y+height)]
                                im1.line(shape, fill="orange", width=2)
                                shape=[(x, y+height),(x+width,y+height) ]
                                im1.line(shape, fill="orange", width=2)
                                shape=[(x, y), (x+width, y)]
                                im1.line(shape, fill="orange", width=2)
                                shape=[(x+width, y),(x+width,y+height) ]
                                im1.line(shape, fill="orange", width=2)
                            elif (type_tle == 'Stĺp (Column sprite)'):
                                shape=[(x, y), (x, y+height)]
                                im1.line(shape, fill="fuchsia", width=2)
                                shape=[(x, y+height),(x+width,y+height) ]
                                im1.line(shape, fill="fuchsia", width=2)
                                shape=[(x, y), (x+width, y)]
                                im1.line(shape, fill="fuchsia", width=2)
                                shape=[(x+width, y),(x+width,y+height) ]
                                im1.line(shape, fill="fuchsia", width=2)
                            elif (type_tle == 'Fontána (Jet, Starter)'):
                                shape=[(x, y), (x, y+height)]
                                im1.line(shape, fill="cyan", width=2)
                                shape=[(x, y+height),(x+width,y+height) ]
                                im1.line(shape, fill="cyan", width=2)
                                shape=[(x, y), (x+width, y)]
                                im1.line(shape, fill="cyan", width=2)
                                shape=[(x+width, y),(x+width,y+height) ]
                                im1.line(shape, fill="cyan", width=2)
                            count+=1
                            print("File %s done." % (event))
                            im.save(os.path.join('annotations', "1%s" % (file))) 
        i+=1
# Out:
# File M20170530_222354_ARBO_P.jpg done.
# File s205550_ARBO.jpg done.
# File s232322_ARBO.jpg done.
# File s231955_ARBO.jpg done.
# File M20170530_205827_ARBO_P.jpg done.
# File s212829_ARBO.jpg done.
# File s222928_ARBO.jpg done.
# File s013140_ARBO.jpg done.
# File s013140_ARBO.jpg done.
# File s235513_ARBO.jpg done.
# File 222045_ARBO.jpg done.
# File 222045_ARBO.jpg done.
# File x204109_ARBO.jpg done.
# File s225613_ARBO.jpg done.
# File s210310_ARBO.jpg done.
# File M20170530_231042_ARBO_P.jpg done.
# File s203752_ARBO.jpg done.
# File s224037_ARBO.jpg done.
# File x203431_VAZEC.jpg done.
# File x203431_VAZEC.jpg done.
# File s211019_ARBO.jpg done.
# File s001019_ARBO.jpg done.
# File x014830_VAZEC.jpg done.
# File x204302_ARBO.jpg done.
# File 224733_KNM.jpg done.
# File s203724_ARBO.jpg done.
# File s204552_ARBO.jpg done.
# File M20170818_213350_ARBO_P.jpg done.
# File x201304_AGO.jpg done.
# File 232131_ARBO.jpg done.
# File M20170530_231939_ARBO_P.jpg done.
# File s231406_ARBO.jpg done.
# File M20170722_203255_ARBO_P.jpg done.
# File s230433_ARBO.jpg done.
# File s230433_ARBO.jpg done.
# File s230433_ARBO.jpg done.
# File s230433_ARBO.jpg done.
# File 231443_KNM.jpg done.
# File M20170827_014504_ARBO_P.jpg done.
# File s203222_ARBO.jpg done.
# File x205912_KNM.jpg done.
# File s211658_ARBO.jpg done.
# File s220052_ARBO.jpg done.
# File M20170720_204449_ARBO_P.jpg done.
# File M20170723_212517_ARBO_P.jpg done.
# File s001921_ARBO.jpg done.
# File 230402_ARBO.jpg done.
# File 201406_KNM.jpg done.
# File M20170530_222634_ARBO_P.jpg done.
# File M20170530_222634_ARBO_P.jpg done.
# File s235131_ARBO.jpg done.
# File 200220_VAZEC.jpg done.
# File s000430_ARBO.jpg done.
# File s223851_ARBO.jpg done.
# File 200203_VAZEC.jpg done.
# File s225317_ARBO.jpg done.
# File s225317_ARBO.jpg done.
# File x232829_ARBO.jpg done.
# File s212037_ARBO.jpg done.
# File 213222_KNM.jpg done.
# File s000233_ARBO.jpg done.
# File s230031_ARBO.jpg done.
# File s230031_ARBO.jpg done.
# File s230031_ARBO.jpg done.
# File M20170720_210417_ARBO_P.jpg done.
# File s211256_ARBO.jpg done.
# File s211950_ARBO.jpg done.
# File x213222_ARBO.jpg done.
# File x213222_ARBO.jpg done.
# File x213222_ARBO.jpg done.
# File s204153_ARBO.jpg done.
# File s202606_ARBO.jpg done.
# File s202606_ARBO.jpg done.
# File M20170705_232126_ARBO_P.jpg done.
# File M20170705_232126_ARBO_P.jpg done.
# File s210955_ARBO.jpg done.
# File M20170801_233932_ARBO_P.jpg done.
# File x234648_KNM.jpg done.
# File s230644_ARBO.jpg done.
# File 232011_AGO.jpg done.
# File y231535_AGO.jpg done.
# File s234916_ARBO.jpg done.
# File M20170723_200408_ARBO_P.jpg done.
# File M20170723_200408_ARBO_P.jpg done.
# File s232905_ARBO.jpg done.
# File s211129_ARBO.jpg done.
# File s001512_ARBO.jpg done.
# File 224306_KNM.jpg done.
# File M20170705_233807_ARBO_P.jpg done.
# File x211511_ARBO.jpg done.
# File 235901_AGO.jpg done.
# File 235901_AGO.jpg done.
# File M20170818_210051_ARBO_P.jpg done.
# File 235901_AGO.jpg done.
# File 235901_AGO.jpg done.
# File M20170801_234130_ARBO_P.jpg done.
# File M20170801_235551_ARBO_P.jpg done.
# File M20170810_002403_ARBO_P.jpg done.
# File M20170810_002403_ARBO_P.jpg done.
# File 212147_ARBO.jpg done.
# File x233915_ARBO.jpg done.
# File 000942_ARBO.jpg done.
# File 000942_ARBO.jpg done.
# File M20170705_231212_ARBO_P.jpg done.
# File 000440_KNM.jpg done.
# File x233528_ARBO.jpg done.
# File M20170801_235110_ARBO_P.jpg done.
# File 212943_ARBO.jpg done.
# File 212943_ARBO.jpg done.
# File 234938_KNM.jpg done.
# File x224351_ARBO.jpg done.
# File x224351_ARBO.jpg done.
# File x224351_ARBO.jpg done.
# File s204804_ARBO.jpg done.
# File s223106_ARBO.jpg done.
# File s223106_ARBO.jpg done.
